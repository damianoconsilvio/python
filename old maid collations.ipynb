# %%
import textract#program command--tells python to use text-extraction/text-reading module
#tells python to recognize the photocopy pdf as text
text = textract.process('oldmaid1.pdf', method = 'tesseract')
book1 = (text)
from nltk.tokenize import sent_tokenize, word_tokenize#designates document, names variable, initiates process
text = textract.process('oldmaid2.pdf', method = 'tesseract')
book2 = (text)
from nltk.tokenize import sent_tokenize, word_tokenize
#creates variable names for files book1 and book2
import difflib
import nltk
import re#imports collation modules/commands
text = textract.process('oldmaid1.pdf', method = 'tesseract')
book1 = text.decode()
text = textract.process('oldmaid2.pdf', method = 'tesseract')
book2 = text.decode()
#names variables
from nltk.tokenize import sent_tokenize, word_tokenize
from IPython.core.display import HTML
#initiates commands for collation and tabulation
words1 = nltk.word_tokenize(book1)
words2 = nltk.word_tokenize(book2)
#renames variables for use in htmldiff
htmldiff = difflib.HtmlDiff()
tbl = htmldiff.make_table(words1, words2, context = True)#sets final collation command
#context equals true command makes the tabulation prioritize differences, marked with n, with surrounding figures
HTML(tbl)
# Out:
#     <table class="diff" id="difflib_chg_to0__top"
#            cellspacing="0" cellpadding="0" rules="groups" >
#         <colgroup></colgroup> <colgroup></colgroup> <colgroup></colgroup>
#         <colgroup></colgroup> <colgroup></colgroup> <colgroup></colgroup>
#
#         <tbody>
#             <tr><td class="diff_next" id="difflib_chg_to0__0"><a href="#difflib_chg_to0__0">f</a></td><td class="diff_header" id="from0_1">1</td><td nowrap="nowrap">THE</td><td class="diff_next"><a href="#difflib_chg_to0__0">f</a></td><td class="diff_header" id="to0_1">1</td><td nowrap="nowrap">THE</td></tr>
#             <tr><td class="diff_next"></td><td class="diff_header" id="from0_2">2</td><td nowrap="nowrap">OLD</td><td class="diff_next"></td><td class="diff_header" id="to0_2">2</td><td nowrap="nowrap">OLD</td></tr>
# ...
